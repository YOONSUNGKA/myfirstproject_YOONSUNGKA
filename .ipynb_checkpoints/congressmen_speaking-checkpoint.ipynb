# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../data/한국재정정보원_재정통계BRIEF_일반회계·특별회계_20211126.csv', encoding = 'cp949')
df
# Out:
#       연도       구분  일반회계 규모(조원)  총지출 대비 비중(퍼센트)  특별회계 규모(조원)  총지출 대비 비중(퍼센트).1  \
# 0   2010       결산        156.4            55.3         43.8              15.5
# 1   2011       결산        168.5            55.4         44.3              14.6
# 2   2012       결산        178.3            55.2         47.0              14.5
# 3   2013       결산        191.6            56.7         47.4              14.0
# 4   2014       결산        198.2            57.0         45.5              13.1
# 5   2015       결산        206.0            55.4         50.9              13.7
# 6   2016       결산        217.1            56.4         47.6              12.4
# 7   2017       결산        225.6            55.5         49.6              12.2
# 8   2018       결산        246.5            57.0         47.2              10.9
# 9   2019       결산        277.7            57.2         51.3              10.6
# 10  2020       결산        320.7            58.4         53.6               9.8
# ...

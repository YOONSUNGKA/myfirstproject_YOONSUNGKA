# %% [markdown]
# * 누구나 이런걸 보면 당연히
# * glob 함수 쓰고, for문을 돌릴 것이다.
# * 첫번째 파일은 제대로 df에 잡히나
# * 두번째부터는 맨 마지막 파일의 회의날짜, 회의명, 회의번호를 뱉어내는
# * 개인적인 생각으로 버그가 발생(아래 사진처럼).
# ![image-3.png](attachment:image-3.png)
# * 파일형식을 바꾸고, 각 파일별 df컬럼별
# * 형변환 다 해보아도 잡아낼 수 없었음.
# * 결국엔 아래와 같이 무식하게 수작업 하여 성공함ㅠㅠ(아래 사진처럼)
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd

# %%
m0 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/000. 국회회의록_21대_379회_1차_국회본회의.csv', index_col = 0)
m1 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/001. 국회회의록_21대_379회_2차_국회본회의.csv', index_col = 0)
m2 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/002. 국회회의록_21대_379회_3차_국회본회의.csv', index_col = 0)
m3 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/003. 국회회의록_21대_379회_4차_국회본회의.csv', index_col = 0)
m4 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/004. 국회회의록_21대_379회_5차_국회본회의.csv', index_col = 0)
m5 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/005. 국회회의록_21대_379회_6차_국회본회의.csv', index_col = 0)
m6 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/006. 국회회의록_21대_379회_7차_국회본회의.csv', index_col = 0)
m7 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/007. 국회회의록_21대_380회_1차_국회본회의.csv', index_col = 0)
m8 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/008. 국회회의록_21대_380회_0차_국회본회의.csv', index_col = 0)
m9 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/009. 국회회의록_21대_380회_2차_국회본회의.csv', index_col = 0)

# %%
m10 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/010. 국회회의록_21대_380회_3차_국회본회의.csv', index_col = 0)
m11 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/011. 국회회의록_21대_380회_4차_국회본회의.csv', index_col = 0)
m12 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/012. 국회회의록_21대_380회_5차_국회본회의.csv', index_col = 0)
m13 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/013. 국회회의록_21대_380회_6차_국회본회의.csv', index_col = 0)
m14 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/014. 국회회의록_21대_380회_7차_국회본회의.csv', index_col = 0)
m15 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/015. 국회회의록_21대_380회_8차_국회본회의.csv', index_col = 0)
m16 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/016. 국회회의록_21대_382회_1차_국회본회의.csv', index_col = 0)
m17 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/017. 국회회의록_21대_382회_0차_국회본회의.csv', index_col = 0)
m18 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/018. 국회회의록_21대_382회_2차_국회본회의.csv', index_col = 0)
m19 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/019. 국회회의록_21대_382회_3차_국회본회의.csv', index_col = 0)

# %%
m20 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/020. 국회회의록_21대_382회_4차_국회본회의.csv', index_col = 0)
m21 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/021. 국회회의록_21대_382회_5차_국회본회의.csv', index_col = 0)
m22 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/022. 국회회의록_21대_382회_6차_국회본회의.csv', index_col = 0)
m23 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/023. 국회회의록_21대_382회_7차_국회본회의.csv', index_col = 0)
m24 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/024. 국회회의록_21대_382회_8차_국회본회의.csv', index_col = 0)
m25 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/025. 국회회의록_21대_382회_9차_국회본회의.csv', index_col = 0)
m26 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/026. 국회회의록_21대_382회_10차_국회본회의.csv', index_col = 0)
m27 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/027. 국회회의록_21대_382회_11차_국회본회의.csv', index_col = 0)
m28 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/028. 국회회의록_21대_382회_12차_국회본회의.csv', index_col = 0)
m29 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/029. 국회회의록_21대_382회_13차_국회본회의.csv', index_col = 0)

# %%
m30 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/030. 국회회의록_21대_382회_14차_국회본회의.csv', index_col = 0)
m31 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/031. 국회회의록_21대_382회_15차_국회본회의.csv', index_col = 0)
m32 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/032. 국회회의록_21대_383회_1차_국회본회의.csv', index_col = 0)
m33 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/033. 국회회의록_21대_383회_2차_국회본회의.csv', index_col = 0)
m34 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/034. 국회회의록_21대_384회_1차_국회본회의.csv', index_col = 0)
m35 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/035. 국회회의록_21대_384회_0차_국회본회의.csv', index_col = 0)
m36 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/036. 국회회의록_21대_384회_2차_국회본회의.csv', index_col = 0)
m37 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/037. 국회회의록_21대_384회_3차_국회본회의.csv', index_col = 0)
m38 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/038. 국회회의록_21대_384회_4차_국회본회의.csv', index_col = 0)
m39 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/039. 국회회의록_21대_384회_5차_국회본회의.csv', index_col = 0)

# %%
m40 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/040. 국회회의록_21대_384회_6차_국회본회의.csv', index_col = 0)
m41 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/041. 국회회의록_21대_384회_7차_국회본회의.csv', index_col = 0)
m42 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/042. 국회회의록_21대_385회_1차_국회본회의.csv', index_col = 0)
m43 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/043. 국회회의록_21대_385회_2차_국회본회의.csv', index_col = 0)
m44 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/044. 국회회의록_21대_385회_3차_국회본회의.csv', index_col = 0)
m45 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/045. 국회회의록_21대_386회_1차_국회본회의.csv', index_col = 0)
m46 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/046. 국회회의록_21대_386회_2차_국회본회의.csv', index_col = 0)
m47 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/047. 국회회의록_21대_386회_3차_국회본회의.csv', index_col = 0)
m48 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/048. 국회회의록_21대_386회_4차_국회본회의.csv', index_col = 0)
m49 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/049. 국회회의록_21대_387회_1차_국회본회의.csv', index_col = 0)

# %%
m50 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/050. 국회회의록_21대_387회_2차_국회본회의.csv', index_col = 0)
m51 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/051. 국회회의록_21대_388회_1차_국회본회의.csv', index_col = 0)
m52 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/052. 국회회의록_21대_388회_2차_국회본회의.csv', index_col = 0)
m53 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/053. 국회회의록_21대_388회_3차_국회본회의.csv', index_col = 0)
m54 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/054. 국회회의록_21대_388회_4차_국회본회의.csv', index_col = 0)
m55 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/055. 국회회의록_21대_388회_5차_국회본회의.csv', index_col = 0)
m56 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/056. 국회회의록_21대_388회_6차_국회본회의.csv', index_col = 0)
m57 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/057. 국회회의록_21대_388회_7차_국회본회의.csv', index_col = 0)
m58 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/058. 국회회의록_21대_389회_1차_국회본회의.csv', index_col = 0)
m59 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/059. 국회회의록_21대_389회_2차_국회본회의.csv', index_col = 0)

# %%
m60 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/060. 국회회의록_21대_389회_3차_국회본회의.csv', index_col = 0)
m61 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/061. 국회회의록_21대_390회_1차_국회본회의.csv', index_col = 0)
m62 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/062. 국회회의록_21대_391회_0차_국회본회의.csv', index_col = 0)
m63 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/063. 국회회의록_21대_391회_1차_국회본회의.csv', index_col = 0)
m64 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/064. 국회회의록_21대_391회_2차_국회본회의.csv', index_col = 0)
m65 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/065. 국회회의록_21대_391회_3차_국회본회의.csv', index_col = 0)
m66 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/066. 국회회의록_21대_391회_4차_국회본회의.csv', index_col = 0)
m67 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/067. 국회회의록_21대_391회_5차_국회본회의.csv', index_col = 0)
m68 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/068. 국회회의록_21대_391회_6차_국회본회의.csv', index_col = 0)
m69 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/069. 국회회의록_21대_391회_7차_국회본회의.csv', index_col = 0)

# %%
m70 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/070. 국회회의록_21대_391회_8차_국회본회의.csv', index_col = 0)
m71 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/071. 국회회의록_21대_391회_9차_국회본회의.csv', index_col = 0)
m72 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/072. 국회회의록_21대_391회_10차_국회본회의.csv', index_col = 0)
m73 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/073. 국회회의록_21대_391회_11차_국회본회의.csv', index_col = 0)
m74 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/074. 국회회의록_21대_391회_12차_국회본회의.csv', index_col = 0)
m75 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/075. 국회회의록_21대_391회_13차_국회본회의.csv', index_col = 0)
m76 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/076. 국회회의록_21대_391회_14차_국회본회의.csv', index_col = 0)
m77 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/077. 국회회의록_21대_392회_1차_국회본회의.csv', index_col = 0)
m78 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/078. 국회회의록_21대_392회_2차_국회본회의.csv', index_col = 0)
m79 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/079. 국회회의록_21대_393회_0차_국회본회의.csv', index_col = 0)

# %%
m80 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/080. 국회회의록_21대_393회_1차_국회본회의.csv', index_col = 0)
m81 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/081. 국회회의록_21대_393회_2차_국회본회의.csv', index_col = 0)
m82 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/082. 국회회의록_21대_393회_3차_국회본회의.csv', index_col = 0)
m83 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/083. 국회회의록_21대_394회_1차_국회본회의.csv', index_col = 0)
m84 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/084. 국회회의록_21대_395회_1차_국회본회의.csv', index_col = 0)
m85 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/085. 국회회의록_21대_395회_2차_국회본회의.csv', index_col = 0)
m86 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/086. 국회회의록_21대_396회_1차_국회본회의.csv', index_col = 0)
m87 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/087. 국회회의록_21대_397회_1차_국회본회의.csv', index_col = 0)
m88 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/088. 국회회의록_21대_397회_2차_국회본회의.csv', index_col = 0)
m89 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/089. 국회회의록_21대_397회_3차_국회본회의.csv', index_col = 0)

# %%
m90 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/090. 국회회의록_21대_397회_4차_국회본회의.csv', index_col = 0)
m91 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/091. 국회회의록_21대_398회_1차_국회본회의.csv', index_col = 0)
m92 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/092. 국회회의록_21대_398회_2차_국회본회의.csv', index_col = 0)
m93 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/093. 국회회의록_21대_398회_3차_국회본회의.csv', index_col = 0)
m94 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/094. 국회회의록_21대_398회_4차_국회본회의.csv.txt', index_col = 0)
m95 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/095. 국회회의록_21대_398회_5차_국회본회의.csv', index_col = 0)
m96 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/096. 국회회의록_21대_398회_6차_국회본회의.csv', index_col = 0)
m97 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/097. 국회회의록_21대_398회_7차_국회본회의.csv', index_col = 0)
m98 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/098. 국회회의록_21대_398회_8차_국회본회의.csv', index_col = 0)
m99 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/099. 국회회의록_21대_400회_1차_국회본회의.csv', index_col = 0)

# %%
m100 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/100. 국회회의록_21대_400회_0차_국회본회의.csv', index_col = 0)
m101 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/101. 국회회의록_21대_400회_2차_국회본회의.csv', index_col = 0)
m102 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/102. 국회회의록_21대_400회_3차_국회본회의.csv', index_col = 0)
m103 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/103. 국회회의록_21대_400회_4차_국회본회의.csv', index_col = 0)
m104 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/104. 국회회의록_21대_400회_5차_국회본회의.csv', index_col = 0)
m105 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/105. 국회회의록_21대_400회_6차_국회본회의.csv', index_col = 0)
m106 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/106. 국회회의록_21대_400회_7차_국회본회의.csv', index_col = 0)
m107 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/107. 국회회의록_21대_400회_8차_국회본회의.csv', index_col = 0)
m108 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/108. 국회회의록_21대_400회_9차_국회본회의.csv', index_col = 0)
m109 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/109. 국회회의록_21대_400회_10차_국회본회의.csv', index_col = 0)

# %%
m110 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/110. 국회회의록_21대_400회_11차_국회본회의.csv', index_col = 0)
m111 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/111. 국회회의록_21대_400회_12차_국회본회의.csv', index_col = 0)
m112 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/112. 국회회의록_21대_400회_13차_국회본회의.csv', index_col = 0)
m113 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/113. 국회회의록_21대_400회_14차_국회본회의.csv', index_col = 0)
m114 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/114. 국회회의록_21대_401회_1차_국회본회의.csv', index_col = 0)
m115 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/115. 국회회의록_21대_401회_2차_국회본회의.csv', index_col = 0)
m116 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/116. 국회회의록_21대_401회_3차_국회본회의.csv', index_col = 0)
m117 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/117. 국회회의록_21대_401회_4차_국회본회의.csv', index_col = 0)
m118 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/118. 국회회의록_21대_401회_5차_국회본회의.csv', index_col = 0)
m119 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/119. 국회회의록_21대_402회_1차_국회본회의.csv', index_col = 0)

# %%
m120 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/120. 국회회의록_21대_403회_0차_국회본회의.csv', index_col = 0)
m121 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/121. 국회회의록_21대_403회_1차_국회본회의.csv', index_col = 0)
m122 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/122. 국회회의록_21대_403회_2차_국회본회의.csv', index_col = 0)
m123 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/123. 국회회의록_21대_403회_3차_국회본회의.csv', index_col = 0)
m124 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/124. 국회회의록_21대_403회_4차_국회본회의.csv', index_col = 0)
m125 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/125. 국회회의록_21대_403회_5차_국회본회의.csv', index_col = 0)
m126 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/126. 국회회의록_21대_403회_6차_국회본회의.csv', index_col = 0)
m127 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/127. 국회회의록_21대_403회_7차_국회본회의.csv', index_col = 0)
m128 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/128. 국회회의록_21대_403회_8차_국회본회의.csv', index_col = 0)
m129 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/129. 국회회의록_21대_404회_1차_국회본회의.csv', index_col = 0)

# %%
m130 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/130. 국회회의록_21대_404회_2차_국회본회의.csv', index_col = 0)
m131 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/131. 국회회의록_21대_405회_1차_국회본회의.csv', index_col = 0)
m132 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/132. 국회회의록_21대_405회_2차_국회본회의.csv', index_col = 0)
m133 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/133. 국회회의록_21대_405회_3차_국회본회의.csv', index_col = 0)
m134 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/134. 국회회의록_21대_405회_4차_국회본회의.csv', index_col = 0)
m135 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/135. 국회회의록_21대_405회_5차_국회본회의.csv', index_col = 0)
m136 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/136. 국회회의록_21대_406회_1차_국회본회의.csv', index_col = 0)
m137 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/137. 국회회의록_21대_406회_2차_국회본회의.csv', index_col = 0)
m138 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/138. 국회회의록_21대_407회_1차_국회본회의.csv', index_col = 0)
m139 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/139. 국회회의록_21대_407회_2차_국회본회의.csv', index_col = 0)

# %%
m140 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/140. 국회회의록_21대_407회_3차_국회본회의.csv', index_col = 0)
m141 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/141. 국회회의록_21대_407회_4차_국회본회의.csv', index_col = 0)
m142 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/142. 국회회의록_21대_407회_5차_국회본회의.csv', index_col = 0)
m143 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/143. 국회회의록_21대_407회_6차_국회본회의.csv', index_col = 0)
m144 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/144. 국회회의록_21대_407회_7차_국회본회의.csv', index_col = 0)
m145 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/145. 국회회의록_21대_408회_1차_국회본회의.csv', index_col = 0)
m146 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/146. 국회회의록_21대_408회_2차_국회본회의.csv', index_col = 0)
m147 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/147. 국회회의록_21대_409회_1차_국회본회의.csv', index_col = 0)
m148 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/148. 국회회의록_21대_410회_1차_국회본회의.csv', index_col = 0)
m149 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/149. 국회회의록_21대_410회_0차_국회본회의.csv', index_col = 0)

# %%
m150 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/150. 국회회의록_21대_410회_2차_국회본회의.csv', index_col = 0)
m151 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/151. 국회회의록_21대_410회_3차_국회본회의.csv', index_col = 0)
m152 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/152. 국회회의록_21대_410회_4차_국회본회의.csv', index_col = 0)
m153 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/153. 국회회의록_21대_410회_5차_국회본회의.csv', index_col = 0)
m154 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/154. 국회회의록_21대_410회_6차_국회본회의.csv', index_col = 0)
m155 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/155. 국회회의록_21대_410회_7차_국회본회의.csv', index_col = 0)
m156 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/156. 국회회의록_21대_410회_8차_국회본회의.csv', index_col = 0)
m157 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/157. 국회회의록_21대_410회_9차_국회본회의.csv', index_col = 0)
m158 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/158. 국회회의록_21대_410회_10차_국회본회의.csv', index_col = 0)
m159 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/159. 국회회의록_21대_410회_11차_국회본회의.csv', index_col = 0)

# %%
m160 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/160. 국회회의록_21대_410회_12차_국회본회의.csv', index_col = 0)
m161 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/161. 국회회의록_21대_410회_13차_국회본회의.csv', index_col = 0)
m162 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/162. 국회회의록_21대_410회_14차_국회본회의.csv', index_col = 0)
m163 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/163. 국회회의록_21대_411회_1차_국회본회의.csv', index_col = 0)
m164 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/164. 국회회의록_21대_411회_2차_국회본회의.csv', index_col = 0)
m165 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/165. 국회회의록_21대_411회_3차_국회본회의.csv', index_col = 0)
m166 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/166. 국회회의록_21대_411회_4차_국회본회의.csv', index_col = 0)
m167 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/167. 국회회의록_21대_412회_1차_국회본회의.csv', index_col = 0)
m168 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/168. 국회회의록_21대_412회_2차_국회본회의.csv', index_col = 0)
m169 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/169. 국회회의록_21대_413회_0차_국회본회의.csv', index_col = 0)

# %%
m170 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/170. 국회회의록_21대_413회_1차_국회본회의.csv', index_col = 0)
m171 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/171. 국회회의록_21대_413회_2차_국회본회의.csv', index_col = 0)
m172 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/172. 국회회의록_21대_413회_3차_국회본회의.csv', index_col = 0)
m173 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/173. 국회회의록_21대_413회_4차_국회본회의.csv', index_col = 0)
m174 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/174. 국회회의록_21대_413회_5차_국회본회의.csv', index_col = 0)
m175 = pd.read_csv('../First_project/dataes/main_congress_meeting_records/175. 국회회의록_21대_413회_6차_국회본회의.csv', index_col = 0)

# %%
total_records = pd.concat([m0, m1,  m2,  m3,  m4,  m5,  m6,  m7,  m8,  m9,
                          m10, m11, m12, m13, m14, m15, m16, m17, m18, m19,
                          m20, m21, m22, m23, m24, m25, m26, m27, m28, m29,
                          m30, m31, m32, m33, m34, m35, m36, m37, m38, m39,
                          m40, m41, m42, m43, m44, m45, m46, m47, m48, m49,
                          m50, m51, m52, m53, m54, m55, m56, m57, m58, m59,
                          m60, m61, m62, m63, m64, m65, m66, m67, m68, m69,
                          m70, m71, m72, m73, m74, m75, m76, m77, m78, m79,
                          m80, m81, m82, m83, m84, m85, m86, m87, m88, m89,
                          m90, m91, m92, m93, m94, m95, m96, m97, m98, m99,
                          m100,m101,m102,m103,m104,m105,m106,m107,m108,m109,
                          m110,m111,m112,m113,m114,m115,m116,m117,m118,m119,
                          m120,m121,m122,m123,m124,m125,m126,m127,m128,m129,
                          m130,m131,m132,m133,m134,m135,m136,m137,m138,m139,
                          m140,m141,m142,m143,m144,m145,m146,m147,m148,m149,
                          m150,m151,m152,m153,m154,m155,m156,m157,m158,m159,
                          m160,m161,m162,m163,m164,m165,m166,m167,m168,m169,
                          m170,m171,m172,m173,m174,m175])
total_records
# Out:
# /var/folders/j7/qsdqw5ms7h31bbj45mcb_n_w0000gn/T/ipykernel_55376/2793692739.py:1: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   total_records = pd.concat([m0, m1,  m2,  m3,  m4,  m5,  m6,  m7,  m8,  m9,
#           date conferNum         commName name  \
# 0   2020-06-05     50024  국회본회의_제379회_제1차  주호영
# 1   2020-06-05     50024  국회본회의_제379회_제1차  김영진
# 2   2020-06-05     50024  국회본회의_제379회_제1차  김상희
# 0   2020-06-10     50027  국회본회의_제379회_제3차  김성원
# 1   2020-06-10     50027  국회본회의_제379회_제3차  김성원
# ..         ...       ...              ...  ...
# 6   2024-02-29     53815  국회본회의_제413회_제6차  강은미
# 7   2024-02-29     53815  국회본회의_제413회_제6차  정희용
# 8   2024-02-29     53815  국회본회의_제413회_제6차  권인숙
# 9   2024-02-29     53815  국회본회의_제413회_제6차  배진교
# ...

# %%
total_records.to_csv('../First_project/dataes/03_21st_main_meeting_total.csv')

# %%
total_records.to_csv('../First_project/dataes/03_21st_main_meeting_total.txt')

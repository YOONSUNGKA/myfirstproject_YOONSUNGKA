# %%
from bs4 import BeautifulSoup 
from urllib.request import Request, urlopen
import re   #정규식(Regular Express)
#절대 경로로 잡힌 url은 그대로 두고 상대경로로 잡힌 url은 절대경로로 변경
from urllib.parse import urljoin
from bs4 import BeautifulStoneSoup
from urllib.request import Request, urlopen

# %%
import pandas as pd
df = pd.read_csv('../../data/1st_project/본회의회의록.csv', encoding = 'cp949')
df
# Out:
#       대수        회의날짜  회의종류명   회의번호                                    회의명  \
# 0     21  2024-02-23  국회본회의  53808  제21대국회 제413회 5차 국회본회의 (2024년 02월 23일)
# 1     21  2024-02-23  국회본회의  53808  제21대국회 제413회 5차 국회본회의 (2024년 02월 23일)
# 2     21  2024-02-22  국회본회의  53804  제21대국회 제413회 4차 국회본회의 (2024년 02월 22일)
# 3     21  2024-02-22  국회본회의  53804  제21대국회 제413회 4차 국회본회의 (2024년 02월 22일)
# 4     21  2024-02-22  국회본회의  53804  제21대국회 제413회 4차 국회본회의 (2024년 02월 22일)
# ...   ..         ...    ...    ...                                    ...
# 1223  21  2020-06-05  국회본회의  50024  제21대국회 제379회 1차 국회본회의 (2020년 06월 05일)
# 1224  21  2020-06-05  국회본회의  50024  제21대국회 제379회 1차 국회본회의 (2020년 06월 05일)
# 1225  21  2020-06-05  국회본회의  50024  제21대국회 제379회 1차 국회본회의 (2020년 06월 05일)
# 1226  21  2020-06-05  국회본회의  50024  제21대국회 제379회 1차 국회본회의 (2020년 06월 05일)
# 1227  21  2020-06-05  국회본회의  50024  제21대국회 제379회 1차 국회본회의 (2020년 06월 05일)
#
#       회의종류코드  영상회의록  안건번호                  안건명  \
# ...

# %%
type(df['요약정보 팝업'][0])
# Out:
# str

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
# 크롬 드라이버 자동 업데이트
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
# 브라우저 꺼짐 방지 - 추가1
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
# 불필요한 에러 메세지 없애기 - 추가3
chrome_options.add_experimental_option("excludeSwitches",
                                       ["enable-logging"])

# %%
service = Service(executable_path = ChromeDriverManager().install())
driver = webdriver.Chrome(service = service, options = chrome_options)

# %%
# type("http://likms.assembly.go.kr/record/mhs-10-030.do?conferNum=050024")
# Out:
# str

# %%
driver.get("http://likms.assembly.go.kr/record/mhs-10-030.do?conferNum=050024") # 050024 ~ 053808

# %%
from selenium.webdriver.common.by import By
driver.find_element(By.XPATH,'//*[@id="wrap"]/div[2]/div/table/tbody/tr/td[1]/span[1]/a').click()

# %%
import warnings
warnings.filterwarnings(action = 'ignore')
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
# 크롬 드라이버 자동 업데이트
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
# 브라우저 꺼짐 방지 - 추가1
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)
# 불필요한 에러 메세지 없애기 - 추가3
chrome_options.add_experimental_option("excludeSwitches",
                                       ["enable-logging"])

service = Service(executable_path = ChromeDriverManager().install())
driver = webdriver.Chrome(service = service, options = chrome_options)

for i in range(len(df.index)):
    driver.get(df['요약정보 팝업'][i])
    driver.find_element(By.XPATH, '//*[@id="wrap"]/div[2]/div/table/tbody/tr/td[1]/span[1]/a').click()

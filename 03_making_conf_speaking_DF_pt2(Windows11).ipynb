# %% [markdown]
# * 윈도우 11 환경

# %%
import glob
import pandas as pd

# %%
meeting_rec= glob.glob('../First_project/dataes/main_congress_meeting_records/*.csv')
meeting_rec
# Out:
# ['../First_project/dataes/main_congress_meeting_records\\000. 국회회의록_21대_379회_1차_국회본회의.csv',
#  '../First_project/dataes/main_congress_meeting_records\\001. 국회회의록_21대_379회_2차_국회본회의.csv',
#  '../First_project/dataes/main_congress_meeting_records\\002. 국회회의록_21대_379회_3차_국회본회의.csv',
#  '../First_project/dataes/main_congress_meeting_records\\003. 국회회의록_21대_379회_4차_국회본회의.csv',
#  '../First_project/dataes/main_congress_meeting_records\\004. 국회회의록_21대_379회_5차_국회본회의.csv',
#  '../First_project/dataes/main_congress_meeting_records\\005. 국회회의록_21대_379회_6차_국회본회의.csv',
#  '../First_project/dataes/main_congress_meeting_records\\006. 국회회의록_21대_379회_7차_국회본회의.csv',
#  '../First_project/dataes/main_congress_meeting_records\\007. 국회회의록_21대_380회_1차_국회본회의.csv',
#  '../First_project/dataes/main_congress_meeting_records\\008. 국회회의록_21대_380회_0차_국회본회의.csv',
#  '../First_project/dataes/main_congress_meeting_records\\009. 국회회의록_21대_380회_2차_국회본회의.csv',
# ...

# %%
df = pd.DataFrame()
for i in meeting_rec:
    tmp = pd.read_csv(i)
    df = pd.concat([df, tmp])
df
# Out:
#    Unnamed: 0        date confer_num      confer_name con_name_kr  \
# 0           0  2020-06-05      50024  국회본회의_제379회_제1차         주호영
# 1           1  2020-06-05      50024  국회본회의_제379회_제1차         김영진
# 2           2  2020-06-05      50024  국회본회의_제379회_제1차         김상희
# 0           0  2020-06-10      50027  국회본회의_제379회_제3차         김성원
# 1           1  2020-06-10      50027  국회본회의_제379회_제3차         김성원
# ..        ...         ...        ...              ...         ...
# 6           6  2024-02-29      53815  국회본회의_제413회_제6차         강은미
# 7           7  2024-02-29      53815  국회본회의_제413회_제6차         정희용
# 8           8  2024-02-29      53815  국회본회의_제413회_제6차         권인숙
# 9           9  2024-02-29      53815  국회본회의_제413회_제6차         배진교
# 10         10  2024-02-29      53815  국회본회의_제413회_제6차         강성희
#
#                                              speaking
# 0   의원님들 반갑습니다.   오늘이 21대 국회 본회의장에서 처음 모이는 날인데 선거 ...
# 1   존경하는 국민 여러분!   존경하는 선후배․동료 의원 여러분!   21대 국회는 법...
# ...

# %%
del df['Unnamed: 0']
df
# Out:
#           date confer_num      confer_name con_name_kr  \
# 0   2020-06-05      50024  국회본회의_제379회_제1차         주호영
# 1   2020-06-05      50024  국회본회의_제379회_제1차         김영진
# 2   2020-06-05      50024  국회본회의_제379회_제1차         김상희
# 0   2020-06-10      50027  국회본회의_제379회_제3차         김성원
# 1   2020-06-10      50027  국회본회의_제379회_제3차         김성원
# ..         ...        ...              ...         ...
# 6   2024-02-29      53815  국회본회의_제413회_제6차         강은미
# 7   2024-02-29      53815  국회본회의_제413회_제6차         정희용
# 8   2024-02-29      53815  국회본회의_제413회_제6차         권인숙
# 9   2024-02-29      53815  국회본회의_제413회_제6차         배진교
# 10  2024-02-29      53815  국회본회의_제413회_제6차         강성희
#
#                                              speaking
# 0   의원님들 반갑습니다.   오늘이 21대 국회 본회의장에서 처음 모이는 날인데 선거 ...
# 1   존경하는 국민 여러분!   존경하는 선후배․동료 의원 여러분!   21대 국회는 법...
# 2   존경하는 국민 여러분!   박병석 의장님을 비롯한 선배․동료 의원 여러분!   제2...
# 0   존경하는 박병석 의장님 그리고 선배․동료 의원 여러분!   경기도 동두천시연천군 출...
# ...

# %%
df.to_csv('03_21st_main_conf_total_tmp.csv')
